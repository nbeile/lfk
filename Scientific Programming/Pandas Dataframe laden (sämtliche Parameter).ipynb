# %% [markdown]
# # Pandas Dataframe laden (sämtliche Parameter)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Dataframe laden

# %%
# Dataframe laden
speicherort = "E:\\Dokumente\\Programmierung\\Python\\Jupyter_Files\\Tutorials\\"
dateiname = "DataframeZuCSV.csv"
df = pd.read_csv(speicherort+dateiname)

# Dataframe anzeigen
df.head()
# Out:
#    Unnamed: 0 first_name last_name  age  preTestScore postTestScore
# 0           0      Jason    Miller   42             4        25,000
# 1           1      Molly  Jacobson   52            24        94,000
# 2           2       Tina       Ali   36            31            57
# 3           3       Jake    Milner   24             2            62
# 4           4        Amy     Cooze   73             3            70

# %% [markdown]
# CSV ohne Header laden

# %%
# CSV ohne Header laden
speicherort = "E:\\Dokumente\\Programmierung\\Python\\Jupyter_Files\\Tutorials\\"
dateiname = "DataframeZuCSV.csv"
df = pd.read_csv(speicherort+dateiname, header=None)

# Dataframe anzeigen
df.head()
# Out:
#      0           1          2    3             4              5
# 0  NaN  first_name  last_name  age  preTestScore  postTestScore
# 1  0.0       Jason     Miller   42             4         25,000
# 2  1.0       Molly   Jacobson   52            24         94,000
# 3  2.0        Tina        Ali   36            31             57
# 4  3.0        Jake     Milner   24             2             62

# %% [markdown]
# CSV mit spezifischen Spaltennamen laden

# %%
# CSV mit spezifischen Spaltennamen laden
speicherort = "E:\\Dokumente\\Programmierung\\Python\\Jupyter_Files\\Tutorials\\"
dateiname = "DataframeZuCSV.csv"
df = pd.read_csv(speicherort+dateiname, names=['UID', 'First Name', 'Last Name', 'Age', 'Pre-Test Score', 'Post-Test Score'])

# Dataframe anzeigen
df.head()
# Out:
#    UID  First Name  Last Name  Age Pre-Test Score Post-Test Score
# 0  NaN  first_name  last_name  age   preTestScore   postTestScore
# 1  0.0       Jason     Miller   42              4          25,000
# 2  1.0       Molly   Jacobson   52             24          94,000
# 3  2.0        Tina        Ali   36             31              57
# 4  3.0        Jake     Milner   24              2              62

# %% [markdown]
# CSV laden und Indexspalte mit 'Index' benennen

# %%
# CSV laden und Indexspalte mit 'Index' benennen
speicherort = "E:\\Dokumente\\Programmierung\\Python\\Jupyter_Files\\Tutorials\\"
dateiname = "DataframeZuCSV.csv"
df = pd.read_csv(speicherort+dateiname, index_col='Index', names=['Index', 'First Name', 'Last Name', 'Age', 'Pre-Test Score', 'Post-Test Score'])

# Dataframe anzeigen
df.head()
# Out:
#        First Name  Last Name  Age Pre-Test Score Post-Test Score
# Index
# NaN    first_name  last_name  age   preTestScore   postTestScore
#  0.0        Jason     Miller   42              4          25,000
#  1.0        Molly   Jacobson   52             24          94,000
#  2.0         Tina        Ali   36             31              57
#  3.0         Jake     Milner   24              2              62

# %% [markdown]
# CSV laden und Zelleninhalt NaN wenn Inhalt = 4

# %%
# CSV laden und Zelleninhalt NaN wenn Inhalt = 4
speicherort = "E:\\Dokumente\\Programmierung\\Python\\Jupyter_Files\\Tutorials\\"
dateiname = "DataframeZuCSV.csv"
df = pd.read_csv(speicherort+dateiname, na_values=['4'])

# Dataframe anzeigen
df.head()
# Out:
#    Unnamed: 0 first_name last_name  age  preTestScore postTestScore
# 0         0.0      Jason    Miller   42           NaN        25,000
# 1         1.0      Molly  Jacobson   52          24.0        94,000
# 2         2.0       Tina       Ali   36          31.0            57
# 3         3.0       Jake    Milner   24           2.0            62
# 4         NaN        Amy     Cooze   73           3.0            70

# %% [markdown]
# CSV laden und Zelleninhalt als Boolean, wenn Zelle NaN ist

# %%
# CSV laden und Zelleninhalt als Boolean, wenn Zelle NaN ist

# CSV laden und Zelleninhalt NaN wenn Inhalt = 4
speicherort = "E:\\Dokumente\\Programmierung\\Python\\Jupyter_Files\\Tutorials\\"
dateiname = "DataframeZuCSV.csv"
df = pd.read_csv(speicherort+dateiname, na_values=['4'])

# Zellen als Boolean, für Nan = True
df1 = pd.isnull(df)

# Dataframe anzeigen
df1.head()
# Out:
#    Unnamed: 0  first_name  last_name    age  preTestScore  postTestScore
# 0       False       False      False  False          True          False
# 1       False       False      False  False         False          False
# 2       False       False      False  False         False          False
# 3       False       False      False  False         False          False
# 4        True       False      False  False         False          False

# %% [markdown]
# CSV laden und erste 3 Reihen überspringen

# %%
# CSV laden und erste 3 Reihen überspringen
speicherort = "E:\\Dokumente\\Programmierung\\Python\\Jupyter_Files\\Tutorials\\"
dateiname = "DataframeZuCSV.csv"
df = pd.read_csv(speicherort+dateiname, skiprows=3)

# Dataframe anzeigen
df.head()
# Out:
#    2  Tina     Ali  36  31  57
# 0  3  Jake  Milner  24   2  62
# 1  4   Amy   Cooze  73   3  70

# %% [markdown]
# Letzte n Zeilen einer CSV laden

# %%
# Letzte n Zeilen einer CSV laden

# Dataframe laden
speicherort = "E:\\Dokumente\\Programmierung\\Python\\Jupyter_Files\\Tutorials\\"
dateiname = "DataframeZuCSV.csv"
df = pd.read_csv(speicherort+dateiname)

# Anzahl n der gewünschten letzten Zeilen
n = 3

# letzten n Zeilen in Variable des Datatframes df1
df1 = df.tail(n)
# Ursprünglisches Dataframe df aus Arbeitsspeicher löschen
df = None

# Dataframe anzeigen
df1.head()
# Out:
#    Unnamed: 0 first_name last_name  age  preTestScore postTestScore
# 2           2       Tina       Ali   36            31            57
# 3           3       Jake    Milner   24             2            62
# 4           4        Amy     Cooze   73             3            70

# %% [markdown]
# CSV laden und Komma als Tausendseperator interpretieren

# %%
# CSV laden und Komma als Tausendseperator interpretieren
speicherort = "E:\\Dokumente\\Programmierung\\Python\\Jupyter_Files\\Tutorials\\"
dateiname = "DataframeZuCSV.csv"
df = pd.read_csv(speicherort+dateiname, thousands=',')

# Dataframe anzeigen
df.head()
# Out:
#    Unnamed: 0 first_name last_name  age  preTestScore  postTestScore
# 0           0      Jason    Miller   42             4          25000
# 1           1      Molly  Jacobson   52            24          94000
# 2           2       Tina       Ali   36            31             57
# 3           3       Jake    Milner   24             2             62
# 4           4        Amy     Cooze   73             3             70
